# %%
import os

# Get the directory where the script is currently located
current_dir = os.path.dirname(os.path.abspath(__file__)) if "__file__" in locals() else os.getcwd()
model_filename = "HRF_Ultimate_v26_LetterRecog.pkl"
model_path = os.path.join(current_dir, model_filename)

if os.path.exists(model_path):
    print(f"⚡ Loading G.O.D. from local workspace: {model_filename}")
    god_model = joblib.load(model_path)
else:
    print(f"❌ Error: {model_filename} not found in {current_dir}")
# Out:
# ⚡ Loading G.O.D. from local workspace: HRF_Ultimate_v26_LetterRecog.pkl
